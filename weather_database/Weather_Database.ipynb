# %%
#import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
#create a new set of 2k random lat and longs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add lats and longs to a list
coordinates = list(lat_lngs)

# %%
#get the nearest city using citipy
#initiate list
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 737

# %%
#API call with OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create weather data DataFrame with the following info
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# initialize list.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 1 | flin flon
# Processing Record 5 of Set 1 | darya khan
# Processing Record 6 of Set 1 | henties bay
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | nelson bay
# Processing Record 11 of Set 1 | coffs harbour
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | lasa
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | gao
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | semnan
# Processing Record 28 of Set 1 | port blair
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | pudozh
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | pemangkat
# Processing Record 37 of Set 1 | santa fe
# Processing Record 38 of Set 1 | sur
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | laukaa
# Processing Record 41 of Set 1 | port hedland
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | koutsouras
# Processing Record 45 of Set 1 | tomatlan
# Processing Record 46 of Set 1 | okha
# Processing Record 47 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 1 | chato
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | barranquilla
# Processing Record 2 of Set 2 | san pedro
# Processing Record 3 of Set 2 | shirokiy
# Processing Record 4 of Set 2 | lata
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | kyra
# Processing Record 7 of Set 2 | olinda
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | mega
# Processing Record 10 of Set 2 | tessalit
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | baruun-urt
# Processing Record 13 of Set 2 | emerald
# Processing Record 14 of Set 2 | hamilton
# Processing Record 15 of Set 2 | cayenne
# Processing Record 16 of Set 2 | davidson
# Processing Record 17 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 18 of Set 2 | benito juarez
# Processing Record 19 of Set 2 | sao felix do xingu
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | zheleznodorozhnyy
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | coquimbo
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | bulgan
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | daru
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | zyuzelskiy
# Processing Record 35 of Set 2 | alibag
# Processing Record 36 of Set 2 | lumphat
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | kununurra
# Processing Record 41 of Set 2 | yumbe
# Processing Record 42 of Set 2 | martinsville
# Processing Record 43 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 2 | gejiu
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | bogorodskoye
# Processing Record 47 of Set 2 | chapais
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | vanavara
# Processing Record 1 of Set 3 | narsaq
# Processing Record 2 of Set 3 | ribeira brava
# Processing Record 3 of Set 3 | ayan
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 3 | codrington
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | chumphon
# Processing Record 9 of Set 3 | matara
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | omboue
# Processing Record 13 of Set 3 | gaya
# Processing Record 14 of Set 3 | jiayuguan
# Processing Record 15 of Set 3 | flinders
# Processing Record 16 of Set 3 | saint george
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | oktyabrskoye
# Processing Record 19 of Set 3 | cairns
# Processing Record 20 of Set 3 | bilibino
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | lodja
# Processing Record 24 of Set 3 | goundam
# Processing Record 25 of Set 3 | lannion
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | willmar
# Processing Record 29 of Set 3 | bosaso
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | bontang
# Processing Record 33 of Set 3 | kedrovyy
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | waitati
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | high level
# Processing Record 42 of Set 3 | tayu
# Processing Record 43 of Set 3 | lorengau
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | tole
# Processing Record 46 of Set 3 | smithers
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | kismayo
# Processing Record 49 of Set 3 | kalmunai
# Processing Record 50 of Set 3 | tocopilla
# Processing Record 1 of Set 4 | chuy
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | komsomolskiy
# Processing Record 4 of Set 4 | cristalina
# Processing Record 5 of Set 4 | taos
# Processing Record 6 of Set 4 | dera ghazi khan
# Processing Record 7 of Set 4 | van
# Processing Record 8 of Set 4 | dongsheng
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | misratah
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | gemena
# Processing Record 14 of Set 4 | tautira
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | rawson
# Processing Record 17 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 4 | pascagoula
# Processing Record 19 of Set 4 | muana
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | algarrobo
# Processing Record 22 of Set 4 | ashland
# Processing Record 23 of Set 4 | huilong
# Processing Record 24 of Set 4 | wick
# Processing Record 25 of Set 4 | daurala
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | quatre cocos
# Processing Record 28 of Set 4 | nouadhibou
# Processing Record 29 of Set 4 | ambulu
# Processing Record 30 of Set 4 | tunceli
# Processing Record 31 of Set 4 | asadabad
# Processing Record 32 of Set 4 | general pico
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | tonantins
# Processing Record 35 of Set 4 | buala
# Processing Record 36 of Set 4 | esna
# Processing Record 37 of Set 4 | braco do norte
# Processing Record 38 of Set 4 | kostomuksha
# Processing Record 39 of Set 4 | besancon
# Processing Record 40 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 41 of Set 4 | portland
# Processing Record 42 of Set 4 | pimenta bueno
# Processing Record 43 of Set 4 | gizo
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | naze
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | kathu
# Processing Record 48 of Set 4 | theologos
# City not found. Skipping...
# Processing Record 49 of Set 4 | bongandanga
# Processing Record 50 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 5 | port alberni
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | padang
# Processing Record 4 of Set 5 | vostok
# Processing Record 5 of Set 5 | baoning
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | alacranes
# Processing Record 9 of Set 5 | hermanus
# Processing Record 10 of Set 5 | charters towers
# Processing Record 11 of Set 5 | novyy urengoy
# Processing Record 12 of Set 5 | new norfolk
# Processing Record 13 of Set 5 | saint anthony
# Processing Record 14 of Set 5 | inta
# Processing Record 15 of Set 5 | cienfuegos
# Processing Record 16 of Set 5 | zharkovskiy
# Processing Record 17 of Set 5 | ouallam
# Processing Record 18 of Set 5 | san juan
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | ixcaquixtla
# City not found. Skipping...
# Processing Record 21 of Set 5 | roma
# Processing Record 22 of Set 5 | kroya
# Processing Record 23 of Set 5 | straseni
# Processing Record 24 of Set 5 | fairbanks
# Processing Record 25 of Set 5 | gat
# Processing Record 26 of Set 5 | tuatapere
# Processing Record 27 of Set 5 | taoudenni
# Processing Record 28 of Set 5 | zhezkazgan
# Processing Record 29 of Set 5 | beloha
# Processing Record 30 of Set 5 | cockburn town
# Processing Record 31 of Set 5 | luangwa
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | sitka
# Processing Record 34 of Set 5 | aksarka
# Processing Record 35 of Set 5 | keflavik
# Processing Record 36 of Set 5 | middelburg
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | boden
# Processing Record 39 of Set 5 | aykhal
# Processing Record 40 of Set 5 | crib point
# Processing Record 41 of Set 5 | dzhebariki-khaya
# Processing Record 42 of Set 5 | arica
# Processing Record 43 of Set 5 | marawi
# Processing Record 44 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 5 | vilyuysk
# Processing Record 46 of Set 5 | salekhard
# Processing Record 47 of Set 5 | kolpashevo
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | constantine
# Processing Record 50 of Set 5 | araouane
# Processing Record 1 of Set 6 | waipawa
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | qaqortoq
# Processing Record 5 of Set 6 | porto novo
# Processing Record 6 of Set 6 | grindavik
# Processing Record 7 of Set 6 | dakar
# Processing Record 8 of Set 6 | ocampo
# Processing Record 9 of Set 6 | mehamn
# Processing Record 10 of Set 6 | morondava
# Processing Record 11 of Set 6 | pangoa
# Processing Record 12 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 13 of Set 6 | andros
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | iqaluit
# Processing Record 16 of Set 6 | gimli
# Processing Record 17 of Set 6 | hefei
# Processing Record 18 of Set 6 | bundaberg
# Processing Record 19 of Set 6 | tirumullaivasal
# Processing Record 20 of Set 6 | manaure
# Processing Record 21 of Set 6 | las cruces
# Processing Record 22 of Set 6 | kuah
# Processing Record 23 of Set 6 | hit
# Processing Record 24 of Set 6 | bay city
# Processing Record 25 of Set 6 | kozhva
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | bairiki
# Processing Record 28 of Set 6 | gorontalo
# Processing Record 29 of Set 6 | oranjemund
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | orocue
# Processing Record 32 of Set 6 | arys
# Processing Record 33 of Set 6 | mitsamiouli
# Processing Record 34 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | jacareacanga
# Processing Record 37 of Set 6 | mixtepec
# City not found. Skipping...
# Processing Record 38 of Set 6 | hovd
# Processing Record 39 of Set 6 | plettenberg bay
# Processing Record 40 of Set 6 | calabozo
# Processing Record 41 of Set 6 | vangaindrano
# Processing Record 42 of Set 6 | kropotkin
# Processing Record 43 of Set 6 | kumla
# Processing Record 44 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | calvinia
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | san vicente
# Processing Record 49 of Set 6 | terekli-mekteb
# Processing Record 50 of Set 6 | yining
# Processing Record 1 of Set 7 | mount gambier
# Processing Record 2 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 3 of Set 7 | xixiang
# Processing Record 4 of Set 7 | burns lake
# Processing Record 5 of Set 7 | victoria
# Processing Record 6 of Set 7 | kolyvan
# Processing Record 7 of Set 7 | nara
# Processing Record 8 of Set 7 | shirvan
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | nome
# Processing Record 11 of Set 7 | naryan-mar
# Processing Record 12 of Set 7 | sao desiderio
# Processing Record 13 of Set 7 | los llanos de aridane
# Processing Record 14 of Set 7 | sayyan
# Processing Record 15 of Set 7 | mar del plata
# Processing Record 16 of Set 7 | ginir
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | piacabucu
# Processing Record 19 of Set 7 | sisimiut
# Processing Record 20 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 7 | newport
# Processing Record 22 of Set 7 | klyuchi
# Processing Record 23 of Set 7 | oudtshoorn
# Processing Record 24 of Set 7 | mahibadhoo
# Processing Record 25 of Set 7 | saint-pierre
# Processing Record 26 of Set 7 | cam ranh
# Processing Record 27 of Set 7 | soe
# Processing Record 28 of Set 7 | helong
# Processing Record 29 of Set 7 | sciacca
# Processing Record 30 of Set 7 | ishigaki
# Processing Record 31 of Set 7 | waddan
# Processing Record 32 of Set 7 | umm kaddadah
# Processing Record 33 of Set 7 | neyshabur
# Processing Record 34 of Set 7 | oxford
# Processing Record 35 of Set 7 | palivere
# Processing Record 36 of Set 7 | gerash
# Processing Record 37 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 7 | redlands
# Processing Record 39 of Set 7 | ulaangom
# Processing Record 40 of Set 7 | qaanaaq
# Processing Record 41 of Set 7 | walvis bay
# Processing Record 42 of Set 7 | yeppoon
# Processing Record 43 of Set 7 | namie
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | karamken
# City not found. Skipping...
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | sura
# Processing Record 49 of Set 7 | akhtanizovskaya
# Processing Record 50 of Set 7 | geraldton
# Processing Record 1 of Set 8 | rong kwang
# Processing Record 2 of Set 8 | verkhoyansk
# Processing Record 3 of Set 8 | vieques
# Processing Record 4 of Set 8 | muroto
# Processing Record 5 of Set 8 | homer
# Processing Record 6 of Set 8 | mayo
# Processing Record 7 of Set 8 | humberto de campos
# Processing Record 8 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 8 | sumbe
# Processing Record 10 of Set 8 | kaffrine
# Processing Record 11 of Set 8 | hauterive
# Processing Record 12 of Set 8 | penzance
# Processing Record 13 of Set 8 | ouanaminthe
# Processing Record 14 of Set 8 | tynda
# Processing Record 15 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | grand-santi
# Processing Record 18 of Set 8 | lalitpur
# Processing Record 19 of Set 8 | sinjar
# Processing Record 20 of Set 8 | klaksvik
# Processing Record 21 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 8 | sakakah
# Processing Record 23 of Set 8 | privodino
# Processing Record 24 of Set 8 | berdigestyakh
# Processing Record 25 of Set 8 | mountain home
# Processing Record 26 of Set 8 | awjilah
# Processing Record 27 of Set 8 | sevilla
# Processing Record 28 of Set 8 | tura
# Processing Record 29 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 8 | zhengjiatun
# Processing Record 31 of Set 8 | port elizabeth
# Processing Record 32 of Set 8 | alot
# Processing Record 33 of Set 8 | rincon
# Processing Record 34 of Set 8 | boa vista
# Processing Record 35 of Set 8 | yantal
# Processing Record 36 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 8 | san andres
# Processing Record 38 of Set 8 | terbuny
# Processing Record 39 of Set 8 | sana
# Processing Record 40 of Set 8 | clyde river
# Processing Record 41 of Set 8 | lephepe
# City not found. Skipping...
# Processing Record 42 of Set 8 | talnakh
# Processing Record 43 of Set 8 | hushitai
# Processing Record 44 of Set 8 | priargunsk
# Processing Record 45 of Set 8 | pitimbu
# Processing Record 46 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | lethem
# Processing Record 50 of Set 8 | san patricio
# Processing Record 1 of Set 9 | prince rupert
# Processing Record 2 of Set 9 | sorland
# Processing Record 3 of Set 9 | nemuro
# Processing Record 4 of Set 9 | omsukchan
# Processing Record 5 of Set 9 | rio grande
# Processing Record 6 of Set 9 | coihaique
# Processing Record 7 of Set 9 | stillwater
# Processing Record 8 of Set 9 | cuamba
# Processing Record 9 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 10 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | haines junction
# Processing Record 12 of Set 9 | monterey
# Processing Record 13 of Set 9 | necochea
# Processing Record 14 of Set 9 | georgetown
# Processing Record 15 of Set 9 | road town
# Processing Record 16 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 9 | faya
# Processing Record 18 of Set 9 | mayumba
# Processing Record 19 of Set 9 | yuzhnyy
# Processing Record 20 of Set 9 | sao gabriel da cachoeira
# Processing Record 21 of Set 9 | bage
# Processing Record 22 of Set 9 | marau
# Processing Record 23 of Set 9 | mattru
# Processing Record 24 of Set 9 | navirai
# Processing Record 25 of Set 9 | moron
# Processing Record 26 of Set 9 | west bay
# Processing Record 27 of Set 9 | koumac
# Processing Record 28 of Set 9 | chifeng
# Processing Record 29 of Set 9 | cheyur
# City not found. Skipping...
# Processing Record 30 of Set 9 | wanning
# Processing Record 31 of Set 9 | tecoanapa
# Processing Record 32 of Set 9 | kuito
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | bachatskiy
# Processing Record 35 of Set 9 | menongue
# Processing Record 36 of Set 9 | salym
# Processing Record 37 of Set 9 | bengkulu
# Processing Record 38 of Set 9 | vilhena
# Processing Record 39 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 40 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | sao filipe
# Processing Record 42 of Set 9 | marsh harbour
# Processing Record 43 of Set 9 | plouzane
# Processing Record 44 of Set 9 | southbridge
# Processing Record 45 of Set 9 | maldonado
# Processing Record 46 of Set 9 | yenagoa
# Processing Record 47 of Set 9 | begowal
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | xai-xai
# Processing Record 50 of Set 9 | cidreira
# Processing Record 1 of Set 10 | eyl
# Processing Record 2 of Set 10 | hobyo
# Processing Record 3 of Set 10 | tevaitoa
# Processing Record 4 of Set 10 | anloga
# Processing Record 5 of Set 10 | sladkovo
# Processing Record 6 of Set 10 | heihe
# Processing Record 7 of Set 10 | andenes
# Processing Record 8 of Set 10 | constitucion
# Processing Record 9 of Set 10 | pravdinskiy
# Processing Record 10 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 10 | caravelas
# Processing Record 12 of Set 10 | paamiut
# Processing Record 13 of Set 10 | maceio
# Processing Record 14 of Set 10 | corner brook
# Processing Record 15 of Set 10 | piryion
# City not found. Skipping...
# Processing Record 16 of Set 10 | muravlenko
# Processing Record 17 of Set 10 | souillac
# Processing Record 18 of Set 10 | ca mau
# Processing Record 19 of Set 10 | viedma
# Processing Record 20 of Set 10 | la ronge
# Processing Record 21 of Set 10 | pundaguitan
# Processing Record 22 of Set 10 | itaporanga
# Processing Record 23 of Set 10 | tarija
# Processing Record 24 of Set 10 | camden
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | ndele
# Processing Record 27 of Set 10 | saldanha
# Processing Record 28 of Set 10 | hun
# Processing Record 29 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 30 of Set 10 | krasnoselkup
# Processing Record 31 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 10 | havre-saint-pierre
# Processing Record 33 of Set 10 | lucapa
# Processing Record 34 of Set 10 | qurayyat
# Processing Record 35 of Set 10 | gari
# Processing Record 36 of Set 10 | fuyu
# Processing Record 37 of Set 10 | gaomi
# Processing Record 38 of Set 10 | warri
# Processing Record 39 of Set 10 | skibbereen
# Processing Record 40 of Set 10 | mantua
# Processing Record 41 of Set 10 | hay river
# Processing Record 42 of Set 10 | notse
# Processing Record 43 of Set 10 | limanowa
# Processing Record 44 of Set 10 | vaitape
# Processing Record 45 of Set 10 | pauini
# Processing Record 46 of Set 10 | rudabanya
# Processing Record 47 of Set 10 | yerbogachen
# Processing Record 48 of Set 10 | monte patria
# Processing Record 49 of Set 10 | grants
# Processing Record 50 of Set 10 | belyy yar
# Processing Record 1 of Set 11 | parambu
# Processing Record 2 of Set 11 | tarko-sale
# Processing Record 3 of Set 11 | svetlyy
# Processing Record 4 of Set 11 | hualmay
# Processing Record 5 of Set 11 | virginia beach
# Processing Record 6 of Set 11 | ust-charyshskaya pristan
# Processing Record 7 of Set 11 | lompoc
# Processing Record 8 of Set 11 | margate
# Processing Record 9 of Set 11 | balabac
# Processing Record 10 of Set 11 | chimbote
# Processing Record 11 of Set 11 | monroe
# Processing Record 12 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 11 | eenhana
# Processing Record 14 of Set 11 | cabedelo
# Processing Record 15 of Set 11 | nueve de julio
# Processing Record 16 of Set 11 | khandbari
# Processing Record 17 of Set 11 | riverton
# Processing Record 18 of Set 11 | saint simons
# Processing Record 19 of Set 11 | pemba
# Processing Record 20 of Set 11 | ihosy
# Processing Record 21 of Set 11 | northam
# Processing Record 22 of Set 11 | rabaul
# Processing Record 23 of Set 11 | savinka
# Processing Record 24 of Set 11 | husavik
# Processing Record 25 of Set 11 | kombissiri
# Processing Record 26 of Set 11 | wangqing
# Processing Record 27 of Set 11 | yulara
# Processing Record 28 of Set 11 | zitiste
# Processing Record 29 of Set 11 | puerto escondido
# Processing Record 30 of Set 11 | cocobeach
# Processing Record 31 of Set 11 | harper
# Processing Record 32 of Set 11 | masallatah
# Processing Record 33 of Set 11 | aranos
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | abomsa
# Processing Record 36 of Set 11 | porto calvo
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | mahon
# Processing Record 39 of Set 11 | alekseyevsk
# Processing Record 40 of Set 11 | pierre
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | povenets
# Processing Record 43 of Set 11 | batemans bay
# Processing Record 44 of Set 11 | vila velha
# Processing Record 45 of Set 11 | ballina
# Processing Record 46 of Set 11 | fort nelson
# Processing Record 47 of Set 11 | yamada
# Processing Record 48 of Set 11 | salamiyah
# Processing Record 49 of Set 11 | hakkari
# Processing Record 50 of Set 11 | canutama
# Processing Record 1 of Set 12 | suntar
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | batagay-alyta
# Processing Record 4 of Set 12 | yangjiang
# Processing Record 5 of Set 12 | kuanshan
# City not found. Skipping...
# Processing Record 6 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 12 | hofn
# Processing Record 8 of Set 12 | enshi
# Processing Record 9 of Set 12 | crowley
# Processing Record 10 of Set 12 | shitanjing
# Processing Record 11 of Set 12 | dingle
# Processing Record 12 of Set 12 | stege
# Processing Record 13 of Set 12 | velsk
# Processing Record 14 of Set 12 | muyezerskiy
# Processing Record 15 of Set 12 | ketchikan
# Processing Record 16 of Set 12 | gladstone
# Processing Record 17 of Set 12 | dinguiraye
# Processing Record 18 of Set 12 | wad madani
# Processing Record 19 of Set 12 | mount isa
# Processing Record 20 of Set 12 | chernyshevskiy
# Processing Record 21 of Set 12 | san borja
# Processing Record 22 of Set 12 | alice springs
# Processing Record 23 of Set 12 | pardina
# Processing Record 24 of Set 12 | tanout
# Processing Record 25 of Set 12 | urubicha
# Processing Record 26 of Set 12 | sainte-thecle
# Processing Record 27 of Set 12 | ballitoville
# Processing Record 28 of Set 12 | muskogee
# Processing Record 29 of Set 12 | podor
# Processing Record 30 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 12 | fomboni
# Processing Record 32 of Set 12 | wukari
# Processing Record 33 of Set 12 | sao goncalo do sapucai
# Processing Record 34 of Set 12 | sri aman
# Processing Record 35 of Set 12 | luena
# Processing Record 36 of Set 12 | lakes entrance
# Processing Record 37 of Set 12 | changchun
# Processing Record 38 of Set 12 | ramon
# Processing Record 39 of Set 12 | ust-nera
# Processing Record 40 of Set 12 | maroantsetra
# Processing Record 41 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 12 | musoma
# Processing Record 43 of Set 12 | boguchany
# Processing Record 44 of Set 12 | kindersley
# Processing Record 45 of Set 12 | macas
# Processing Record 46 of Set 12 | aleksandrovskiy zavod
# Processing Record 47 of Set 12 | salinas
# Processing Record 48 of Set 12 | we
# City not found. Skipping...
# Processing Record 49 of Set 12 | cap malheureux
# Processing Record 50 of Set 12 | valpacos
# Processing Record 1 of Set 13 | aksu
# Processing Record 2 of Set 13 | avon
# Processing Record 3 of Set 13 | itarema
# Processing Record 4 of Set 13 | sug-aksy
# City not found. Skipping...
# Processing Record 5 of Set 13 | maarianhamina
# Processing Record 6 of Set 13 | santo antonio do ica
# Processing Record 7 of Set 13 | storsteinnes
# Processing Record 8 of Set 13 | amapa
# Processing Record 9 of Set 13 | nakhon nayok
# Processing Record 10 of Set 13 | conde
# Processing Record 11 of Set 13 | boende
# Processing Record 12 of Set 13 | milkovo
# Processing Record 13 of Set 13 | tarrafal
# Processing Record 14 of Set 13 | kuvandyk
# Processing Record 15 of Set 13 | honningsvag
# Processing Record 16 of Set 13 | opuwo
# Processing Record 17 of Set 13 | banjar
# Processing Record 18 of Set 13 | atar
# Processing Record 19 of Set 13 | sao joao da barra
# Processing Record 20 of Set 13 | nyurba
# Processing Record 21 of Set 13 | samarai
# Processing Record 22 of Set 13 | saint-augustin
# Processing Record 23 of Set 13 | plainview
# Processing Record 24 of Set 13 | shakiso
# Processing Record 25 of Set 13 | chhabra
# Processing Record 26 of Set 13 | pangody
# Processing Record 27 of Set 13 | sehithwa
# Processing Record 28 of Set 13 | cabinda
# Processing Record 29 of Set 13 | san lorenzo
# Processing Record 30 of Set 13 | qasigiannguit
# Processing Record 31 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 13 | takoradi
# Processing Record 34 of Set 13 | muros
# Processing Record 35 of Set 13 | taungdwingyi
# Processing Record 36 of Set 13 | marzuq
# Processing Record 37 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 38 of Set 13 | almiros
# City not found. Skipping...
# Processing Record 39 of Set 13 | maragogi
# Processing Record 40 of Set 13 | aitape
# Processing Record 41 of Set 13 | bhawanipatna
# Processing Record 42 of Set 13 | shimoda
# Processing Record 43 of Set 13 | tezu
# Processing Record 44 of Set 13 | zhangye
# Processing Record 45 of Set 13 | vao
# Processing Record 46 of Set 13 | zyryanka
# Processing Record 47 of Set 13 | aqtobe
# Processing Record 48 of Set 13 | muzquiz
# City not found. Skipping...
# Processing Record 49 of Set 13 | ahipara
# Processing Record 50 of Set 13 | egvekinot
# Processing Record 1 of Set 14 | alikovo
# Processing Record 2 of Set 14 | lashio
# Processing Record 3 of Set 14 | mugur-aksy
# Processing Record 4 of Set 14 | taitung
# Processing Record 5 of Set 14 | aleppo
# Processing Record 6 of Set 14 | avera
# Processing Record 7 of Set 14 | caranavi
# Processing Record 8 of Set 14 | anadyr
# Processing Record 9 of Set 14 | faanui
# Processing Record 10 of Set 14 | kaeo
# Processing Record 11 of Set 14 | powell river
# Processing Record 12 of Set 14 | ulladulla
# Processing Record 13 of Set 14 | beringovskiy
# Processing Record 14 of Set 14 | alofi
# Processing Record 15 of Set 14 | hanzhong
# Processing Record 16 of Set 14 | mirabad
# Processing Record 17 of Set 14 | petrove
# Processing Record 18 of Set 14 | rorvik
# Processing Record 19 of Set 14 | san-pedro
# Processing Record 20 of Set 14 | kostroma
# Processing Record 21 of Set 14 | ust-omchug
# Processing Record 22 of Set 14 | uravakonda
# Processing Record 23 of Set 14 | phoenixville
# Processing Record 24 of Set 14 | bitung
# Processing Record 25 of Set 14 | thaton
# Processing Record 26 of Set 14 | bartlesville
# Processing Record 27 of Set 14 | alice
# Processing Record 28 of Set 14 | xining
# Processing Record 29 of Set 14 | bozdar
# Processing Record 30 of Set 14 | jinhua
# Processing Record 31 of Set 14 | jalu
# Processing Record 32 of Set 14 | burdur
# Processing Record 33 of Set 14 | rock springs
# Processing Record 34 of Set 14 | dolores
# Processing Record 35 of Set 14 | sabang
# Processing Record 36 of Set 14 | hellvik
# Processing Record 37 of Set 14 | kozluk
# Processing Record 38 of Set 14 | carlsbad
# Processing Record 39 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 14 | jiuquan
# Processing Record 42 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 14 | camana
# Processing Record 44 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 45 of Set 14 | alice town
# Processing Record 46 of Set 14 | kavaratti
# Processing Record 47 of Set 14 | tipuani
# Processing Record 48 of Set 14 | tabou
# Processing Record 49 of Set 14 | izhma
# Processing Record 50 of Set 14 | vidor
# Processing Record 1 of Set 15 | hami
# Processing Record 2 of Set 15 | oktyabrskiy
# Processing Record 3 of Set 15 | raymondville
# Processing Record 4 of Set 15 | golpayegan
# Processing Record 5 of Set 15 | hyeres
# Processing Record 6 of Set 15 | fukue
# Processing Record 7 of Set 15 | wainwright
# Processing Record 8 of Set 15 | vrangel
# Processing Record 9 of Set 15 | irtyshskiy
# Processing Record 10 of Set 15 | skalnyy
# City not found. Skipping...
# Processing Record 11 of Set 15 | puerto quijarro
# Processing Record 12 of Set 15 | hervey bay
# Processing Record 13 of Set 15 | pa sang
# Processing Record 14 of Set 15 | tairua
# Processing Record 15 of Set 15 | gamba
# Processing Record 16 of Set 15 | fayaoue
# Processing Record 17 of Set 15 | auki
# Processing Record 18 of Set 15 | arkhangelsk
# Processing Record 19 of Set 15 | zabol
# Processing Record 20 of Set 15 | oksfjord
# Processing Record 21 of Set 15 | tra vinh
# Processing Record 22 of Set 15 | maniitsoq
# Processing Record 23 of Set 15 | bathsheba
# Processing Record 24 of Set 15 | riyadh
# Processing Record 25 of Set 15 | fort frances
# Processing Record 26 of Set 15 | kahului
# Processing Record 27 of Set 15 | san rafael
# Processing Record 28 of Set 15 | makakilo city
# Processing Record 29 of Set 15 | abu samrah
# Processing Record 30 of Set 15 | almaznyy
# Processing Record 31 of Set 15 | sarangani
# Processing Record 32 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 15 | lamu
# Processing Record 34 of Set 15 | sekoma
# Processing Record 35 of Set 15 | arlit
# Processing Record 36 of Set 15 | silver city
# Processing Record 37 of Set 15 | mordovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
#convert to Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vaini      TO -21.2000 -175.2000     82.56        78          75
# 1      Flin Flon      CA  54.7682 -101.8650     30.51        89         100
# 2     Darya Khan      PK  31.7912   71.1039     66.06        30           0
# 3    Henties Bay      NA -22.1160   14.2845     60.85        92           0
# 4   Punta Arenas      CL -53.1500  -70.9167     51.91        50           0
# 5      Esperance      AU -33.8667  121.9000     72.88        44         100
# 6        Ushuaia      AR -54.8000  -68.3000     46.06        71           0
# 7     Nelson Bay      AU -32.7167  152.1500     75.96        57         100
# 8  Coffs Harbour      AU -30.3000  153.1333     69.76        56          90
# 9        Rikitea      PF -23.1203 -134.9692     73.08        78         100
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1        7.70     overcast clouds
# 2        8.08           clear sky
# 3        6.40           clear sky
# 4       16.11           clear sky
# 5       15.21     overcast clouds
# 6        6.91           clear sky
# 7        1.99     overcast clouds
# 8        8.05     overcast clouds
# 9       17.69     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
